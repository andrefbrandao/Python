# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
IPCA = pd.read_excel('expectativas FOCUS 26-12 .xls', sheet_name = 0, index_col = 0)
CAMBIO = pd.read_excel('expectativas FOCUS 26-12 .xls', sheet_name = 1, index_col = 0)
SELIC = pd.read_excel('expectativas FOCUS 26-12 .xls', sheet_name = 2, index_col = 0)
PIB = pd.read_excel('expectativas FOCUS 26-12 .xls', sheet_name = 3, index_col = 0)

# %%
IPCA
# Out:
#             2020  2021  2022    2023    2024  2025  2026  2027
# 2020-01-02   3.6  3.75   3.5  3.5000     NaN   NaN   NaN   NaN
# 2020-01-03   3.6  3.75   3.5  3.5000     NaN   NaN   NaN   NaN
# 2020-01-06   3.6  3.75   3.5  3.5000     NaN   NaN   NaN   NaN
# 2020-01-07   3.6  3.75   3.5  3.5000     NaN   NaN   NaN   NaN
# 2020-01-08   3.6  3.75   3.5  3.5000     NaN   NaN   NaN   NaN
# ...          ...   ...   ...     ...     ...   ...   ...   ...
# 2023-12-18   NaN   NaN   NaN  4.4859  3.9238   3.5   3.5   3.5
# 2023-12-19   NaN   NaN   NaN  4.4859  3.9200   3.5   3.5   3.5
# 2023-12-20   NaN   NaN   NaN  4.4859  3.9200   3.5   3.5   3.5
# 2023-12-21   NaN   NaN   NaN  4.4755  3.9200   3.5   3.5   3.5
# 2023-12-22   NaN   NaN   NaN  4.4590  3.9068   3.5   3.5   3.5
#
# [998 rows x 8 columns]

# %%
fig, ((ax2, ax4), (ax6, ax8)) = plt.subplots(2, 2, figsize=(20, 15))  # 2 linhas, 4 colunas



# gráfico 2
ax2.plot(IPCA[2023], label='2023')
ax2.plot(IPCA[2024], label='2024')
ax2.plot(IPCA[2025], label='2025')
ax2.plot(IPCA[2026], label='2026')
ax2.set_title('Expectativas de mercado - 2023 a 2026', fontsize=14)
ax2.set_ylabel('IPCA', fontsize=14) 
ax2.legend()
ax2.grid()



# gráfico 4
ax4.plot(CAMBIO[2023], label='2023')
ax4.plot(CAMBIO[2024], label='2024')
ax4.plot(CAMBIO[2025], label='2025')
ax4.plot(CAMBIO[2026], label='2026')
ax4.set_title('Expectativas de mercado - 2023 a 2026', fontsize=14)
ax4.set_ylabel('Câmbio', fontsize=14) 
ax4.legend()
ax4.grid()


# gráfico 6
ax6.plot(SELIC[2023], label='2023')
ax6.plot(SELIC[2024], label='2024')
ax6.plot(SELIC[2025], label='2025')
ax6.plot(SELIC[2026], label='2026')
ax6.set_title('Expectativas de mercado - 2023 a 2026', fontsize=14)
ax6.set_ylabel('SELIC', fontsize=14) 
ax6.legend()
ax6.grid()


# gráfico 8
ax8.plot(PIB[2023], label='2023')
ax8.plot(PIB[2024], label='2024')
ax8.plot(PIB[2025], label='2025')
ax8.plot(PIB[2026], label='2026')
ax8.set_title('Expectativas de mercado - 2023 a 2026', fontsize=14)
ax8.set_ylabel('PIB', fontsize=14) 
ax8.legend()
ax8.grid()


plt.subplots_adjust(hspace=0.4)


plt.savefig('expectativas 26-12 ajustadas.pdf')
